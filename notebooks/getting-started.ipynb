# %% [markdown]
# # Installation

# %%
! pip install breast-cancer-toolkit

# %% [markdown]
# # Read images
#
# The read function accepts a path to DICOM files, classic images (such as TIFF, JPG, PNG), and NPY files, and returns a Tensor.

# %%
from breast_cancer_toolkit.pipeline import read

# %%
read('../assets/D_4606_1.LEFT_CC.LJPEG.tiff').plot()

# %%
read('../assets/A_0243_1.LEFT_CC.tif.npy').plot()

# %%
read('https://github.com/sanchezcarlosjr/breast-cancer-toolkit/raw/main/assets/D_4606_1.LEFT_CC.LJPEG.tiff').plot()
