# %% [markdown]
# # Installation

# %%
! pip install breast-cancer-toolkit

# %% [markdown]
# # Read images
#
# The read function accepts a path to DICOM files, classic images (such as TIFF, JPG, PNG), and NPY files, and returns a Pillow image.

# %%
from breast_cancer_toolkit.pipeline import read

# %%
read('../assets/D_4606_1.LEFT_CC.LJPEG.tiff').plot()

# %%
import glob
import random
files = list(range(0,8))
random.sample(files, min(5,len(files)))
# Out:
# [6, 3, 1, 7, 5]
